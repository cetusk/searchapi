# %%
# import module "searchapi"
import searchapi as sa

# %%
# create logger instance
logs = { "counter": [0], "overwrite": True }
# execute
sa.search(modulename="numpy", keyname="full", maxdepth=3, strict=False, logger=logs)
# Out:
# [30787]: Successfully finished.
#  --  --  -- numpy.char.numpy.core.full ( accuracy: 100.0 % )
#  --  --  -- numpy.char.numpy.core.full_like ( accuracy: 44.4 % )
#  --  -- numpy.char.numpy.full ( accuracy: 100.0 % )
#  --  -- numpy.char.numpy.full_like ( accuracy: 44.4 % )
#  --  --  -- numpy.char.numpy.version.full_version ( accuracy: 33.3 % )
#  --  --  -- numpy.char.sys.displayhook.do_full_cache ( accuracy: 30.8 % )
#  --  --  -- numpy.compat.pickle.re.fullmatch ( accuracy: 44.4 % )
#  --  --  -- numpy.core.arrayprint.np.full ( accuracy: 100.0 % )
#  --  --  -- numpy.core.arrayprint.np.full_like ( accuracy: 44.4 % )
#  --  --  -- numpy.core.char.numpy.full ( accuracy: 100.0 % )
#  --  --  -- numpy.core.char.numpy.full_like ( accuracy: 44.4 % )
#  --  --  -- numpy.core.defchararray.numpy.full ( accuracy: 100.0 % )
#  --  --  -- numpy.core.defchararray.numpy.full_like ( accuracy: 44.4 % )
#  --  --  -- numpy.core.fromnumeric.np.full ( accuracy: 100.0 % )
# ...
